# %% [markdown]
# # From Python to Production — Day 2
# ## Notebook 2: Operators & Control Flow
# By **Prerna Joshi** | #25DaysOfDataTech
#
# "Programming starts making sense once you understand how Python makes decisions."
#
# ---
#
# ### 📌 What you'll learn:
# - Arithmetic, comparison, logical, assignment operators
# - Membership & identity operators
# - Expression execution rules
# - Division & modulo behavior
# - Control flow: if/elif/else
# - Operator precedence (which operations run first)
# - Mini practice problems

# %% [markdown]
# ## 1. Why Operators Matter
#
# Operators let Python:
# - calculate values
# - compare data
# - combine conditions
# - decide what happens next
#
# In data workflows, operators are used in:
# - fraud detection
# - eligibility checks
# - filtering rows
# - validation rules

# %% [markdown]
# ## 2. Arithmetic Operators
#
# | Operator | Meaning | Example |
# |---------|---------|---------|
# | `+` | Addition | `10 + 5` |
# | `-` | Subtraction | `10 - 3` |
# | `*` | Multiplication | `5 * 3` |
# | `/` | Division (float) | `10 / 4` → 2.5 |
# | `//` | Floor Division | `10 // 4` → 2 |
# | `%` | Modulus (remainder) | `10 % 4` |
# | `**` | Exponent | `2 ** 3` |
#
# Let's try them:

# %%
a, b = 10, 4

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)
print("Modulus:", a % b)
print("Exponent:", a ** b)
# Out:
# Addition: 14
# Subtraction: 6
# Multiplication: 40
# Division: 2.5
# Floor Division: 2
# Modulus: 2
# Exponent: 10000

# %% [markdown]
# ### Example: Compute tax-inclusive amount

# %%
amount = 450.75
tax_rate = 0.18
total_amount = amount + (amount * tax_rate)
print("Total amount including tax:", total_amount)
# Out:
# Total amount including tax: 531.885

# %% [markdown]
# ## 3. Assignment Operators
#
# These update the value of a variable:
#
# | Operator | Meaning | Example |
# |----------|----------|---------|
# | `+=` | Add & assign | `x += 2` |
# | `-=` | Subtract & assign | `x -= 3` |
# | `*=` | Multiply & assign | `x *= 5` |
# | `/=` | Divide & assign | `x /= 2` |
# | `//=` | Floor divide & assign | `x //= 3` |
# | `%=` | Modulus & assign | `x %= 4` |
# | `**=` | Power & assign | `x **= 2` |
#
# Used frequently in loops, counters, and aggregations.

# %%
x = 10
x += 5
x
# Out:
# 15

# %% [markdown]
# ## 4. Comparison Operators
#
# Used to compare values.
#
# | Operator | Meaning |
# |---------|----------|
# | `==` | Equal |
# | `!=` | Not equal |
# | `>` | Greater than |
# | `<` | Less than |
# | `>=` | Greater or equal |
# | `<=` | Less or equal |

# %%
amount = 1200
amount > 1000, amount != 1200, amount != 500
# Out:
# (True, False, True)

# %% [markdown]
# ## 5. Logical Operators
#
# | Operator | Meaning |
# |---------|----------|
# | `and` | both conditions true |
# | `or` | any condition true |
# | `not` | reverses truth value |

# %%
score = 85
passed = score > 50 and score != 0
passed
# Out:
# True

# %% [markdown]
# ## 6. Expression Execution Rules
#
# ### ✔ 1. String × Integer → repetition
# `"@" * 3` → `"@@@"`
#
# ### ✔ 2. String + String → concatenation
# `"Py" + "thon"` → `"Python"`
#
# ### ✔ 3. Numeric values work with all arithmetic operators
#
# ### ✔ 4. int + float → result is always float

# %%
txt = "@"

# In Python, multiplying a string by an integer repeats the string.
# Example:
# "@" * 3  → "@@@"
# This is often used for formatting or creating simple text patterns.

result = 2 * txt * 3   # Evaluates left to right → (2 * "@") * 3  → "@@" * 3 → "@@@@@@"
print(result)
# Out:
# @@@@@@

# %%
A = "2"
B = "3"
T = "@"

# String + string results in concatenation.
# Example:
# "2" + "@"  → "2@"
# And then ("2@" * 3) → "2@2@2@"

# Order:
# 1. (A + T) → "2@"
# 2. (A + T) * 3 → "2@2@2@"
# 3. (A + T)*3 + B → "2@2@2@" + "3" → "2@2@2@3"

pattern = (A + T) * 3 + B
print(pattern)
# Out:
# 2@2@2@3

# %% [markdown]
# ## 7. Division Behavior in Python
#
# ### ✔ `/` always gives float
# `1 / 2` → `0.5`
#
# ### ✔ `//` floor division
# - int // int → int
# - float // int → float
#
# ### ✔ Floor division = floor(A / B)

# %%
# In Python, "/" always performs TRUE division and returns a float.
# Example:
# 5 / 2 = 2.5

# "//" performs FLOOR division:
# It divides the numbers and then rounds DOWN to the nearest whole number.
# Example:
# 5 // 2 → 2   (because floor(2.5) = 2)

# When at least ONE operand is a float (e.g., 5.0 // 2),
# the result is STILL floored, but Python keeps the type as float.

print(5 // 2, 5 / 2)
# Output:
# 5 // 2 → 2      (floor division, integer result)
# 5 / 2  → 2.5    (true division)

print(5.0 // 2, 5.0 / 2)
# Output:
# 5.0 // 2 → 2.0  (floor division, float result because operand was float)
# 5.0 / 2  → 2.5  (true division)
# Out:
# 2 2.5
# 2.0 2.5

# %% [markdown]
# ## 8. Modulo (%) Rules with Negative Numbers
#
# Python follows: result = numerator − denominator × floor(numerator / denominator)
#
# Which means:
# The modulo operator (%) returns the REMAINDER after division.
# Example:
# 5 % 2 → 1        (because 5 = 2*2 + 1)
#
# Python follows the rule:
# A % B = A - B * floor(A / B)
#
#
#
# | A | B | A % B |
# |---|---|-------|
# | 5 | 2 | 1 |
# | 5 | -2 | -1 |
# | -5 | 2 | 1 |
# | -5 | -2 | -1 |

# %%
# Modulo (%) Rules
# Let's explore positive and negative combinations.
print(5 % 2)     # 1  → normal positive remainder
print(5 % -2)    # -1 → denominator is negative → remainder also negative
print(-5 % 2)    # 1  → numerator negative → result shifts to positive remainder
print(-5 % -2)   # -1 → both negative → floor rule produces negative remainder

# These follow Python’s consistent mathematical definition,
# which is important in algorithms, hashing, and index rotation.
# Out:
# 1
# -1
# 1
# -1

# %% [markdown]
# ## 9. Operator Precedence in Python
#
# Python follows this order (highest → lowest):
#
# 1. `**`
# 2. `*`, `/`, `//`, `%`
# 3. `+`, `-`
# 4. Comparison operators
# 5. Logical `not`
# 6. Logical `and`
# 7. Logical `or`
#
# ### Example:
# `4 + 2 * 3` → `10`

# %%
print(4 + 2 * 3)
print((4 + 2) * 3)
# Out:
# 10
# 18

# %% [markdown]
# ## 10. Control Flow (if / elif / else)
#
# Below is a simple flow diagram:
#
#       ┌──────────────┐
#       │   CONDITION  │
#       └───────┬──────┘
#               │
#        True   │   False
#       ┌───────┘────────┐
#
# Python checks conditions **top to bottom**.

# %%
amount = 700

if amount > 1000:
    print("High-value transaction")
elif amount > 500:
    print("Medium-value transaction")
else:
    print("Low-value transaction")
# Out:
# Medium-value transaction

# %% [markdown]
# ## 11. Practice Exercises
# Try these:
#
# 1️⃣ Check if a number is even or odd
# Input: `num = 7` → Output: `Odd`
#
# 2️⃣ Password strength check:
# - length > 8
# - contains "@"
# - contains number
#
# 3️⃣ Given age, print:
# - Child (< 13)
# - Teen (13–19)
# - Adult (20–59)
# - Senior (60+)

# %% [markdown]
# # 📝 Summary of Notebook 2
#
# You learned:
#
# ✔ Arithmetic, comparison, logical, assignment operators
# ✔ Expression execution rules
# ✔ Division & modulo behavior
# ✔ If/elif/else decisions
# ✔ Operator precedence
# ✔ Real-world examples (fraud, thresholds)
# ✔ Practice exercises
#
# Next:
# 👉 **Notebook 3 — Loops in Depth**

# %% [markdown]
# ---
#
# ## 12. Practice Exercise Solutions
# *(Click to reveal the answers only after trying the exercises yourself.)*

# %% [markdown]
# <details>
# <summary><strong>Solution 1️⃣ — Even or Odd</strong></summary>
#
# ```python
# num = 7
#
# if num % 2 == 0:
#     print("Even")
# else:
#     print("Odd")

# %% [markdown]
# <details>
# <summary><strong>Solution 2️⃣ — Password Strength Check</strong></summary>
#
# ```python
# password = "Hello@123"
#
# has_min_length = len(password) > 8
# has_special = "@" in password
# has_number = any(ch.isdigit() for ch in password)
#
# if has_min_length and has_special and has_number:
#     print("Strong Password")
# else:
#     print("Weak Password")

# %% [markdown]
# <details>
# <summary><strong>Solution 3️⃣ — Age Category</strong></summary>
#
# ```python
# age = 45
#
# if age < 13:
#     print("Child")
# elif age <= 19:
#     print("Teen")
# elif age <= 59:
#     print("Adult")
# else:
#     print("Senior")
