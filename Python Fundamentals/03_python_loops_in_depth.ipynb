# %% [markdown]
# # From Python to Production — Day 2
# ## Notebook 3: Loops in Depth
# By **Prerna Joshi** | #25DaysOfDataTech
#
# "Loops are the heartbeat of automation — almost every data task repeats."
#
# ---
#
# ### 📌 What you'll learn in this notebook:
# - For loops
# - While loops
# - Loop control statements (`break`, `continue`, `pass`)
# - Nested loops
# - Looping through lists, dictionaries, strings
# - Range() explained
# - Practical loops for ETL, validation, and preprocessing
# - Beginner-friendly exercises
# - Optional solutions

# %% [markdown]
# ## 1. Why Loops Matter
#
# Loops let Python repeat actions efficiently.
#
# In real-world data roles, loops are used for:
# - Iterating over rows in a dataset
# - Validating records
# - Cleaning text fields
# - Building features
# - Sending API calls
# - Processing streaming events
#
# Mastering loops is key to writing clean, efficient Python.

# %% [markdown]
# ## 2. For Loops
#
# A `for` loop repeats actions for every item in a sequence.
#
# Basic structure:

# %%
for i in [1, 2, 3]:
    print("Number:", i)
# Out:
# Number: 1
# Number: 2
# Number: 3

# %% [markdown]
# ## 3. The range() Function
#
# `range()` generates a sequence of numbers.
#
# Useful for:
# - Running loops N times
# - Creating counters
# - Index-based iteration

# %%
for i in range(5):         # 0 → 4
    print(i)

for i in range(2, 6):      # 2 → 5
    print(i)

for i in range(0, 10, 2):  # even numbers
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 2
# 3
# 4
# 5
# 0
# 2
# 4
# 6
# 8

# %% [markdown]
# ## 4. While Loops
#
# A `while` loop runs **as long as a condition is true**.

# %%
count = 1

while count <= 5:
    print("Count:", count)
    count += 1
# Out:
# Count: 1
# Count: 2
# Count: 3
# Count: 4
# Count: 5

# %% [markdown]
# ## 5. Loop Control Statements
#
# | Keyword | Meaning |
# |--------|----------|
# | `break` | Stop the loop immediately |
# | `continue` | Skip the current iteration and continue |
# | `pass` | Do nothing (placeholder) |

# %%
for num in range(1, 10):
    if num == 5:
        break  # stop loop when 5 is reached
    print(num)
# Out:
# 1
# 2
# 3
# 4

# %%
for num in range(1, 10):
    if num % 2 == 0:
        continue  # skip even numbers
    print(num)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(5):
    pass  # placeholder for future logic
print("Loop ran successfully")
# Out:
# Loop ran successfully

# %% [markdown]
# ## 6. Nested Loops
#
# A loop inside another loop.
#
# Useful for:
# - Matrix operations
# - Comparing every pair of items
# - Building combinations

# %%
for i in range(1, 4):
    for j in range(1, 4):
        print(f"({i}, {j})")
# Out:
# (1, 1)
# (1, 2)
# (1, 3)
# (2, 1)
# (2, 2)
# (2, 3)
# (3, 1)
# (3, 2)
# (3, 3)

# %% [markdown]
# ### Example: Validate records in batches

# %%
records = [
    {"id": 1, "value": 50},
    {"id": 2, "value": -3},   # invalid
    {"id": 3, "value": 80},
]

for record in records:
    if record["value"] < 0:
        print("Invalid record:", record)
        continue
    print("Valid record:", record)
# Out:
# Valid record: {'id': 1, 'value': 50}
# Invalid record: {'id': 2, 'value': -3}
# Valid record: {'id': 3, 'value': 80}

# %% [markdown]
# ## 7. Looping through Dictionaries

# %%
student = {"name": "Prerna", "age": 25, "score": 92}

for key in student:
    print(key, "→", student[key])

for key, value in student.items():
    print(key, "=", value)
# Out:
# name → Prerna
# age → 25
# score → 92
# name = Prerna
# age = 25
# score = 92

# %% [markdown]
# > 💡 Fun Fact:
# > 80% of beginner Python bugs come from loops — missing conditions, infinite loops, or misusing break/continue.

# %% [markdown]
# ## 8. Practice Exercises
#
# Try these:
#
# ### 1️⃣ Print numbers from 1 to 20 except multiples of 3
# (Hint: use continue)
#
# ### 2️⃣ Sum all values in a list
# Input: `[10, 20, 30, 40]` → Output: `100`
#
# ### 3️⃣ Count how many valid records exist
# A record is valid if `value >= 0`.
#
# ### 4️⃣ Print a multiplication table for any number
# Example: 5 → 5,10,15,...50
#
# ### 5️⃣ Nested Loop Challenge
# Print all pairs `(i, j)` for i = 1 to 3 and j = 1 to 2.

# %% [markdown]
# ## 9. Practice Solutions
# *(Click to reveal the answers only after solving.)*
#
# <details>
# <summary><strong>Solutions </strong></summary>
#
# ```python
# #1️⃣
# for i in range(1, 21):
#     if i % 3 == 0:
#         continue
#     print(i)
#
# #2️⃣
# nums = [10, 20, 30, 40]
# total = 0
#
# for n in nums:
#     total += n
#
# total
#
# #3️⃣
# records = [10, -5, 30, -2, 50]
# count = 0
#
# for r in records:
#     if r >= 0:
#         count += 1
#
# count
#
# #4️⃣
# n = 5
# for i in range(1, 11):
#     print(n * i)
#
# # 5️⃣
# for i in range(1, 4):
#     for j in range(1, 3):
#         print((i, j))
#
#
# ```

# %% [markdown]
# # 📝 Summary of Notebook 3
#
# You learned:
#
# ✔ For loops
# ✔ While loops
# ✔ break, continue, pass
# ✔ Nested loops
# ✔ Looping through lists & dictionaries
# ✔ range()
# ✔ Validation examples
# ✔ Multiple practice exercises with solutions
#
# Next:
# 👉 **Notebook 4 — Functions & Scope (LEGB Rule)**
